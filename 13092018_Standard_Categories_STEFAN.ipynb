# %% [markdown]
# # Getting the cateogries into separate columns

# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = 150

# %%
df = pd.read_csv('12092018_Dataframe_with_categories_benjaminv2.csv')

# %%
df['Classification_set'].apply(str)[0:5]
# Out:
# 0                                                  nan
# 1    A,A01,A01N,A,A01,A01N,A,A61,A61N,A,A61,A61F,A,...
# 2          A,A23,A23B,A,A23,A23B,A,A23,A23B,A,A23,A23B
# 3    A,A23,A23C,A,A23,A23C,A,A23,A23C,A,A23,A23L,A,...
# 4                     A,A23,A23L,A,A61,A61K,A,A61,A61K
# Name: Classification_set, dtype: object

# %%
df['Classification_set'] = df['Classification_set'].str.split(',')

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df.fillna(value=0, inplace=True)

# %%
df.loc[:]['Class1'] = df.loc[:]['Classification_set']

# %%
l = df['Classification_set']

# %%
l = list(l)

# %%
df1 = df.iloc[1:]

# %%
l1 = l[1:]

# %%
df_clean = df1.loc[df1['Classification_set'] != 0]

# %%
df_clean['Class1'] = [list(e)[0] for e in df_clean['Classification_set']]
df_clean['1Sub1'] = [list(e)[1] for e in df_clean['Classification_set']]
df_clean['1Sub2'] = [list(e)[2] for e in df_clean['Classification_set']]
df_clean['Class2'] = [list(e)[3] if len(list(e)) > 3 else np.nan for e in df_clean['Classification_set']]
df_clean['2Sub1'] = [list(e)[4] if len(list(e)) > 3 else np.nan for e in df_clean['Classification_set']]
df_clean['2Sub2'] = [list(e)[5] if len(list(e)) > 3 else np.nan for e in df_clean['Classification_set']]
df_clean['Class3'] = [list(e)[6] if len(list(e)) > 6 else np.nan for e in df_clean['Classification_set']]
df_clean['3Sub1'] = [list(e)[7] if len(list(e)) > 6 else np.nan for e in df_clean['Classification_set']]
df_clean['3Sub2'] = [list(e)[8] if len(list(e)) > 6 else np.nan for e in df_clean['Classification_set']]
df_clean['Class4'] = [list(e)[9] if len(list(e)) > 9 else np.nan for e in df_clean['Classification_set']]
df_clean['4sub1'] = [list(e)[10] if len(list(e)) > 9 else np.nan for e in df_clean['Classification_set']]
df_clean['4sub2'] = [list(e)[11] if len(list(e)) > 9 else np.nan for e in df_clean['Classification_set']]
df_clean['Class5'] = [list(e)[12] if len(list(e)) > 12 else np.nan for e in df_clean['Classification_set']]
df_clean['5sub1'] = [list(e)[13] if len(list(e)) > 12 else np.nan for e in df_clean['Classification_set']]
df_clean['5sub2'] = [list(e)[14] if len(list(e)) > 12 else np.nan for e in df_clean['Classification_set']]
df_clean['Class6'] = [list(e)[15] if len(list(e)) > 15 else np.nan for e in df_clean['Classification_set']]
df_clean['6sub1'] = [list(e)[16] if len(list(e)) > 15 else np.nan for e in df_clean['Classification_set']]
df_clean['6sub2'] = [list(e)[17] if len(list(e)) > 15 else np.nan for e in df_clean['Classification_set']]
df_clean['Class7'] = [list(e)[18] if len(list(e)) > 18 else np.nan for e in df_clean['Classification_set']]
df_clean['7sub1'] = [list(e)[19] if len(list(e)) > 18 else np.nan for e in df_clean['Classification_set']]
df_clean['7sub2'] = [list(e)[20] if len(list(e)) > 18 else np.nan for e in df_clean['Classification_set']]
df_clean['Class8'] = [list(e)[21] if len(list(e)) > 21 else np.nan for e in df_clean['Classification_set']]
df_clean['8sub1'] = [list(e)[22] if len(list(e)) > 21 else np.nan for e in df_clean['Classification_set']]
df_clean['8sub2'] = [list(e)[23] if len(list(e)) > 21 else np.nan for e in df_clean['Classification_set']]
df_clean['Class9'] = [list(e)[24] if len(list(e)) > 24 else np.nan for e in df_clean['Classification_set']]
df_clean['9sub1'] = [list(e)[25] if len(list(e)) > 24 else np.nan for e in df_clean['Classification_set']]
df_clean['9sub2'] = [list(e)[26] if len(list(e)) > 24 else np.nan for e in df_clean['Classification_set']]
df_clean['Class10'] = [list(e)[27] if len(list(e)) > 27 else np.nan for e in df_clean['Classification_set']]
df_clean['10sub1'] = [list(e)[28] if len(list(e)) > 27 else np.nan for e in df_clean['Classification_set']]
df_clean['10sub2'] = [list(e)[29] if len(list(e)) > 27 else np.nan for e in df_clean['Classification_set']]
df_clean['Class11'] = [list(e)[30] if len(list(e)) > 30 else np.nan for e in df_clean['Classification_set']]
df_clean['11sub1'] = [list(e)[31] if len(list(e)) > 30 else np.nan for e in df_clean['Classification_set']]
df_clean['11sub2'] = [list(e)[32] if len(list(e)) > 30 else np.nan for e in df_clean['Classification_set']]
df_clean['Class12'] = [list(e)[33] if len(list(e)) > 33 else np.nan for e in df_clean['Classification_set']]
df_clean['12sub1'] = [list(e)[34] if len(list(e)) > 33 else np.nan for e in df_clean['Classification_set']]
df_clean['12sub2'] = [list(e)[35] if len(list(e)) > 33 else np.nan for e in df_clean['Classification_set']]
df_clean['Class13'] = [list(e)[36] if len(list(e)) > 36 else np.nan for e in df_clean['Classification_set']]
df_clean['13sub1'] = [list(e)[37] if len(list(e)) > 36 else np.nan for e in df_clean['Classification_set']]
df_clean['13sub2'] = [list(e)[38] if len(list(e)) > 36 else np.nan for e in df_clean['Classification_set']]
df_clean['Class14'] = [list(e)[39] if len(list(e)) > 39 else np.nan for e in df_clean['Classification_set']]
df_clean['14sub1'] = [list(e)[40] if len(list(e)) > 39 else np.nan for e in df_clean['Classification_set']]
df_clean['14sub2'] = [list(e)[41] if len(list(e)) > 39 else np.nan for e in df_clean['Classification_set']]
df_clean['Class15'] = [list(e)[42] if len(list(e)) > 42 else np.nan for e in df_clean['Classification_set']]
df_clean['15sub1'] = [list(e)[43] if len(list(e)) > 42 else np.nan for e in df_clean['Classification_set']]
df_clean['15sub2'] = [list(e)[44] if len(list(e)) > 42 else np.nan for e in df_clean['Classification_set']]
df_clean['Class16'] = [list(e)[45] if len(list(e)) > 45 else np.nan for e in df_clean['Classification_set']]
df_clean['16sub1'] = [list(e)[46] if len(list(e)) > 45 else np.nan for e in df_clean['Classification_set']]
df_clean['16sub2'] = [list(e)[47] if len(list(e)) > 45 else np.nan for e in df_clean['Classification_set']]
df_clean['Class17'] = [list(e)[48] if len(list(e)) > 48 else np.nan for e in df_clean['Classification_set']]
df_clean['17sub1'] = [list(e)[49] if len(list(e)) > 48 else np.nan for e in df_clean['Classification_set']]
df_clean['17sub2'] = [list(e)[50] if len(list(e)) > 48 else np.nan for e in df_clean['Classification_set']]
df_clean['Class18'] = [list(e)[51] if len(list(e)) > 51 else np.nan for e in df_clean['Classification_set']]
df_clean['18sub1'] = [list(e)[52] if len(list(e)) > 51 else np.nan for e in df_clean['Classification_set']]
df_clean['18sub2'] = [list(e)[53] if len(list(e)) > 51 else np.nan for e in df_clean['Classification_set']]
df_clean['Class19'] = [list(e)[54] if len(list(e)) > 54 else np.nan for e in df_clean['Classification_set']]
df_clean['19sub1'] = [list(e)[55] if len(list(e)) > 54 else np.nan for e in df_clean['Classification_set']]
df_clean['19sub2'] = [list(e)[56] if len(list(e)) > 54 else np.nan for e in df_clean['Classification_set']]
df_clean['Class20'] = [list(e)[57] if len(list(e)) > 57 else np.nan for e in df_clean['Classification_set']]
df_clean['20sub1'] = [list(e)[58] if len(list(e)) > 57 else np.nan for e in df_clean['Classification_set']]
df_clean['20sub2'] = [list(e)[59] if len(list(e)) > 57 else np.nan for e in df_clean['Classification_set']]
df_clean['Class21'] = [list(e)[60] if len(list(e)) > 60 else np.nan for e in df_clean['Classification_set']]
df_clean['21sub1'] = [list(e)[61] if len(list(e)) > 60 else np.nan for e in df_clean['Classification_set']]
df_clean['21sub2'] = [list(e)[62] if len(list(e)) > 60 else np.nan for e in df_clean['Classification_set']]
df_clean['Class22'] = [list(e)[63] if len(list(e)) > 63 else np.nan for e in df_clean['Classification_set']]
df_clean['22sub1'] = [list(e)[64] if len(list(e)) > 63 else np.nan for e in df_clean['Classification_set']]
df_clean['22sub2'] = [list(e)[65] if len(list(e)) > 63 else np.nan for e in df_clean['Classification_set']]
df_clean['Class23'] = [list(e)[66] if len(list(e)) > 66 else np.nan for e in df_clean['Classification_set']]
df_clean['23sub1'] = [list(e)[67] if len(list(e)) > 66 else np.nan for e in df_clean['Classification_set']]
df_clean['23sub2'] = [list(e)[68] if len(list(e)) > 66 else np.nan for e in df_clean['Classification_set']]
df_clean['Class24'] = [list(e)[69] if len(list(e)) > 69 else np.nan for e in df_clean['Classification_set']]
df_clean['24sub1'] = [list(e)[70] if len(list(e)) > 69 else np.nan for e in df_clean['Classification_set']]
df_clean['24sub2'] = [list(e)[71] if len(list(e)) > 69 else np.nan for e in df_clean['Classification_set']]
df_clean['Class23'] = [list(e)[72] if len(list(e)) > 72 else np.nan for e in df_clean['Classification_set']]
df_clean['23sub1'] = [list(e)[73] if len(list(e)) > 72 else np.nan for e in df_clean['Classification_set']]
df_clean['23sub2'] = [list(e)[74] if len(list(e)) > 72 else np.nan for e in df_clean['Classification_set']]
df_clean['Class24'] = [list(e)[75] if len(list(e)) > 75 else np.nan for e in df_clean['Classification_set']]
df_clean['24sub1'] = [list(e)[76] if len(list(e)) > 75 else np.nan for e in df_clean['Classification_set']]
df_clean['24sub2'] = [list(e)[77] if len(list(e)) > 75 else np.nan for e in df_clean['Classification_set']]
df_clean['Class25'] = [list(e)[78] if len(list(e)) > 78 else np.nan for e in df_clean['Classification_set']]
df_clean['25sub1'] = [list(e)[79] if len(list(e)) > 78 else np.nan for e in df_clean['Classification_set']]
df_clean['25sub2'] = [list(e)[80] if len(list(e)) > 78 else np.nan for e in df_clean['Classification_set']]

df_clean['Class26'] = [list(e)[81] if len(list(e)) > 81 else np.nan for e in df_clean['Classification_set']]
df_clean['26sub1'] = [list(e)[82] if len(list(e)) > 81 else np.nan for e in df_clean['Classification_set']]
df_clean['26sub2'] = [list(e)[83] if len(list(e)) > 81 else np.nan for e in df_clean['Classification_set']]
df_clean['Class27'] = [list(e)[84] if len(list(e)) > 84 else np.nan for e in df_clean['Classification_set']]
df_clean['27sub1'] = [list(e)[85] if len(list(e)) > 84 else np.nan for e in df_clean['Classification_set']]
df_clean['27sub2'] = [list(e)[86] if len(list(e)) > 84 else np.nan for e in df_clean['Classification_set']]
df_clean['Class28'] = [list(e)[87] if len(list(e)) > 87 else np.nan for e in df_clean['Classification_set']]
df_clean['28sub1'] = [list(e)[88] if len(list(e)) > 87 else np.nan for e in df_clean['Classification_set']]
df_clean['28sub2'] = [list(e)[89] if len(list(e)) > 87 else np.nan for e in df_clean['Classification_set']]
df_clean['Class29'] = [list(e)[90] if len(list(e)) > 90 else np.nan for e in df_clean['Classification_set']]
df_clean['29sub1'] = [list(e)[91] if len(list(e)) > 90 else np.nan for e in df_clean['Classification_set']]
df_clean['29sub2'] = [list(e)[92] if len(list(e)) > 90 else np.nan for e in df_clean['Classification_set']]
df_clean['Class30'] = [list(e)[93] if len(list(e)) > 93 else np.nan for e in df_clean['Classification_set']]
df_clean['30sub1'] = [list(e)[94] if len(list(e)) > 93 else np.nan for e in df_clean['Classification_set']]
df_clean['30sub2'] = [list(e)[95] if len(list(e)) > 93 else np.nan for e in df_clean['Classification_set']]
df_clean['Class31'] = [list(e)[96] if len(list(e)) > 96 else np.nan for e in df_clean['Classification_set']]
df_clean['31sub1'] = [list(e)[97] if len(list(e)) > 96 else np.nan for e in df_clean['Classification_set']]
df_clean['31sub2'] = [list(e)[98] if len(list(e)) > 96 else np.nan for e in df_clean['Classification_set']]
df_clean['Class32'] = [list(e)[99] if len(list(e)) > 99 else np.nan for e in df_clean['Classification_set']]
df_clean['32sub1'] = [list(e)[100] if len(list(e)) > 99 else np.nan for e in df_clean['Classification_set']]
df_clean['32sub2'] = [list(e)[101] if len(list(e)) > 99 else np.nan for e in df_clean['Classification_set']]

df_clean['Class33'] = [list(e)[102] if len(list(e)) > 102 else np.nan for e in df_clean['Classification_set']]
df_clean['33sub1'] = [list(e)[103] if len(list(e)) > 102 else np.nan for e in df_clean['Classification_set']]
df_clean['33sub2'] = [list(e)[104] if len(list(e)) > 102 else np.nan for e in df_clean['Classification_set']]
df_clean['Class34'] = [list(e)[105] if len(list(e)) > 105 else np.nan for e in df_clean['Classification_set']]
df_clean['34sub1'] = [list(e)[106] if len(list(e)) > 105 else np.nan for e in df_clean['Classification_set']]
df_clean['34sub2'] = [list(e)[107] if len(list(e)) > 105 else np.nan for e in df_clean['Classification_set']]
df_clean['Class35'] = [list(e)[108] if len(list(e)) > 108 else np.nan for e in df_clean['Classification_set']]
df_clean['35sub1'] = [list(e)[109] if len(list(e)) > 108 else np.nan for e in df_clean['Classification_set']]
df_clean['35sub2'] = [list(e)[110] if len(list(e)) > 108 else np.nan for e in df_clean['Classification_set']]
df_clean['Class36'] = [list(e)[111] if len(list(e)) > 111 else np.nan for e in df_clean['Classification_set']]
df_clean['36sub1'] = [list(e)[112] if len(list(e)) > 111 else np.nan for e in df_clean['Classification_set']]
df_clean['36sub2'] = [list(e)[113] if len(list(e)) > 111 else np.nan for e in df_clean['Classification_set']]
df_clean['Class37'] = [list(e)[114] if len(list(e)) > 114 else np.nan for e in df_clean['Classification_set']]
df_clean['37sub1'] = [list(e)[115] if len(list(e)) > 114 else np.nan for e in df_clean['Classification_set']]
df_clean['37sub2'] = [list(e)[116] if len(list(e)) > 114 else np.nan for e in df_clean['Classification_set']]
df_clean['Class38'] = [list(e)[117] if len(list(e)) > 117 else np.nan for e in df_clean['Classification_set']]
df_clean['38sub1'] = [list(e)[118] if len(list(e)) > 117 else np.nan for e in df_clean['Classification_set']]
df_clean['38sub2'] = [list(e)[119] if len(list(e)) > 117 else np.nan for e in df_clean['Classification_set']]
df_clean['Class39'] = [list(e)[120] if len(list(e)) > 120 else np.nan for e in df_clean['Classification_set']]
df_clean['39sub1'] = [list(e)[121] if len(list(e)) > 120 else np.nan for e in df_clean['Classification_set']]
df_clean['39sub2'] = [list(e)[122] if len(list(e)) > 120 else np.nan for e in df_clean['Classification_set']]

df_clean['Class40'] = [list(e)[123] if len(list(e)) > 123 else np.nan for e in df_clean['Classification_set']]
df_clean['40sub1'] = [list(e)[124] if len(list(e)) > 123 else np.nan for e in df_clean['Classification_set']]
df_clean['40sub2'] = [list(e)[125] if len(list(e)) > 123 else np.nan for e in df_clean['Classification_set']]
df_clean['Class41'] = [list(e)[126] if len(list(e)) > 126 else np.nan for e in df_clean['Classification_set']]
df_clean['41sub1'] = [list(e)[127] if len(list(e)) > 126 else np.nan for e in df_clean['Classification_set']]
df_clean['41sub2'] = [list(e)[128] if len(list(e)) > 126 else np.nan for e in df_clean['Classification_set']]
df_clean['Class42'] = [list(e)[129] if len(list(e)) > 129 else np.nan for e in df_clean['Classification_set']]
df_clean['42sub1'] = [list(e)[130] if len(list(e)) > 129 else np.nan for e in df_clean['Classification_set']]
df_clean['42sub2'] = [list(e)[131] if len(list(e)) > 129 else np.nan for e in df_clean['Classification_set']]
df_clean['Class43'] = [list(e)[132] if len(list(e)) > 132 else np.nan for e in df_clean['Classification_set']]
df_clean['43sub1'] = [list(e)[133] if len(list(e)) > 132 else np.nan for e in df_clean['Classification_set']]
df_clean['43sub2'] = [list(e)[134] if len(list(e)) > 132 else np.nan for e in df_clean['Classification_set']]
df_clean['Class44'] = [list(e)[135] if len(list(e)) > 135 else np.nan for e in df_clean['Classification_set']]
df_clean['44sub1'] = [list(e)[136] if len(list(e)) > 135 else np.nan for e in df_clean['Classification_set']]
df_clean['44sub2'] = [list(e)[137] if len(list(e)) > 135 else np.nan for e in df_clean['Classification_set']]
df_clean['Class45'] = [list(e)[138] if len(list(e)) > 138 else np.nan for e in df_clean['Classification_set']]
df_clean['45sub1'] = [list(e)[139] if len(list(e)) > 138 else np.nan for e in df_clean['Classification_set']]
df_clean['45sub2'] = [list(e)[140] if len(list(e)) > 138 else np.nan for e in df_clean['Classification_set']]
df_clean['Class46'] = [list(e)[141] if len(list(e)) > 141 else np.nan for e in df_clean['Classification_set']]
df_clean['46sub1'] = [list(e)[142] if len(list(e)) > 141 else np.nan for e in df_clean['Classification_set']]
df_clean['46sub2'] = [list(e)[143] if len(list(e)) > 141 else np.nan for e in df_clean['Classification_set']]

df_clean['Class47'] = [list(e)[144] if len(list(e)) > 144 else np.nan for e in df_clean['Classification_set']]
df_clean['47sub1'] = [list(e)[145] if len(list(e)) > 144 else np.nan for e in df_clean['Classification_set']]
df_clean['47sub2'] = [list(e)[146] if len(list(e)) > 144 else np.nan for e in df_clean['Classification_set']]
df_clean['Class48'] = [list(e)[147] if len(list(e)) > 147 else np.nan for e in df_clean['Classification_set']]
df_clean['48sub1'] = [list(e)[148] if len(list(e)) > 147 else np.nan for e in df_clean['Classification_set']]
df_clean['48sub2'] = [list(e)[149] if len(list(e)) > 147 else np.nan for e in df_clean['Classification_set']]
df_clean['Class49'] = [list(e)[150] if len(list(e)) > 150 else np.nan for e in df_clean['Classification_set']]
df_clean['49sub1'] = [list(e)[151] if len(list(e)) > 150 else np.nan for e in df_clean['Classification_set']]
df_clean['49sub2'] = [list(e)[152] if len(list(e)) > 150 else np.nan for e in df_clean['Classification_set']]
df_clean['Class50'] = [list(e)[153] if len(list(e)) > 153 else np.nan for e in df_clean['Classification_set']]
df_clean['50sub1'] = [list(e)[154] if len(list(e)) > 153 else np.nan for e in df_clean['Classification_set']]
df_clean['50sub2'] = [list(e)[155] if len(list(e)) > 153 else np.nan for e in df_clean['Classification_set']]
df_clean['Class51'] = [list(e)[156] if len(list(e)) > 156 else np.nan for e in df_clean['Classification_set']]
df_clean['51sub1'] = [list(e)[157] if len(list(e)) > 156 else np.nan for e in df_clean['Classification_set']]
df_clean['51sub2'] = [list(e)[158] if len(list(e)) > 156 else np.nan for e in df_clean['Classification_set']]
df_clean['Class52'] = [list(e)[159] if len(list(e)) > 159 else np.nan for e in df_clean['Classification_set']]
df_clean['52sub1'] = [list(e)[160] if len(list(e)) > 159 else np.nan for e in df_clean['Classification_set']]
df_clean['52sub2'] = [list(e)[161] if len(list(e)) > 159 else np.nan for e in df_clean['Classification_set']]
df_clean['Class53'] = [list(e)[162] if len(list(e)) > 162 else np.nan for e in df_clean['Classification_set']]
df_clean['53sub1'] = [list(e)[163] if len(list(e)) > 162 else np.nan for e in df_clean['Classification_set']]
df_clean['53sub2'] = [list(e)[164] if len(list(e)) > 162 else np.nan for e in df_clean['Classification_set']]

df_clean['Class54'] = [list(e)[165] if len(list(e)) > 165 else np.nan for e in df_clean['Classification_set']]
df_clean['54sub1'] = [list(e)[166] if len(list(e)) > 165 else np.nan for e in df_clean['Classification_set']]
df_clean['54sub2'] = [list(e)[167] if len(list(e)) > 165 else np.nan for e in df_clean['Classification_set']]
df_clean['Class55'] = [list(e)[168] if len(list(e)) > 168 else np.nan for e in df_clean['Classification_set']]
df_clean['55sub1'] = [list(e)[169] if len(list(e)) > 168 else np.nan for e in df_clean['Classification_set']]
df_clean['55sub2'] = [list(e)[170] if len(list(e)) > 168 else np.nan for e in df_clean['Classification_set']]
df_clean['Class56'] = [list(e)[171] if len(list(e)) > 171 else np.nan for e in df_clean['Classification_set']]
df_clean['56sub1'] = [list(e)[172] if len(list(e)) > 171 else np.nan for e in df_clean['Classification_set']]
df_clean['56sub2'] = [list(e)[173] if len(list(e)) > 171 else np.nan for e in df_clean['Classification_set']]
df_clean['Class57'] = [list(e)[174] if len(list(e)) > 174 else np.nan for e in df_clean['Classification_set']]
df_clean['57sub1'] = [list(e)[175] if len(list(e)) > 174 else np.nan for e in df_clean['Classification_set']]
df_clean['57sub2'] = [list(e)[176] if len(list(e)) > 174 else np.nan for e in df_clean['Classification_set']]
df_clean['Class58'] = [list(e)[177] if len(list(e)) > 177 else np.nan for e in df_clean['Classification_set']]
df_clean['58sub1'] = [list(e)[178] if len(list(e)) > 177 else np.nan for e in df_clean['Classification_set']]
df_clean['58sub2'] = [list(e)[179] if len(list(e)) > 177 else np.nan for e in df_clean['Classification_set']]
df_clean['Class59'] = [list(e)[180] if len(list(e)) > 180 else np.nan for e in df_clean['Classification_set']]
df_clean['59sub1'] = [list(e)[181] if len(list(e)) > 180 else np.nan for e in df_clean['Classification_set']]
df_clean['59sub2'] = [list(e)[182] if len(list(e)) > 180 else np.nan for e in df_clean['Classification_set']]
df_clean['Class60'] = [list(e)[183] if len(list(e)) > 183 else np.nan for e in df_clean['Classification_set']]
df_clean['60sub1'] = [list(e)[184] if len(list(e)) > 183 else np.nan for e in df_clean['Classification_set']]
df_clean['60sub2'] = [list(e)[185] if len(list(e)) > 183 else np.nan for e in df_clean['Classification_set']]

df_clean['Class61'] = [list(e)[186] if len(list(e)) > 186 else np.nan for e in df_clean['Classification_set']]
df_clean['61sub1'] = [list(e)[187] if len(list(e)) > 186 else np.nan for e in df_clean['Classification_set']]
df_clean['61sub2'] = [list(e)[188] if len(list(e)) > 186 else np.nan for e in df_clean['Classification_set']]
df_clean['Class62'] = [list(e)[189] if len(list(e)) > 189 else np.nan for e in df_clean['Classification_set']]
df_clean['62sub1'] = [list(e)[190] if len(list(e)) > 189 else np.nan for e in df_clean['Classification_set']]
df_clean['62sub2'] = [list(e)[191] if len(list(e)) > 189 else np.nan for e in df_clean['Classification_set']]
df_clean['Class63'] = [list(e)[192] if len(list(e)) > 192 else np.nan for e in df_clean['Classification_set']]
df_clean['63sub1'] = [list(e)[193] if len(list(e)) > 192 else np.nan for e in df_clean['Classification_set']]
df_clean['63sub2'] = [list(e)[194] if len(list(e)) > 192 else np.nan for e in df_clean['Classification_set']]
df_clean['Class64'] = [list(e)[195] if len(list(e)) > 195 else np.nan for e in df_clean['Classification_set']]
df_clean['64sub1'] = [list(e)[196] if len(list(e)) > 195 else np.nan for e in df_clean['Classification_set']]
df_clean['64sub2'] = [list(e)[197] if len(list(e)) > 195 else np.nan for e in df_clean['Classification_set']]
df_clean['Class65'] = [list(e)[198] if len(list(e)) > 198 else np.nan for e in df_clean['Classification_set']]
df_clean['65sub1'] = [list(e)[199] if len(list(e)) > 198 else np.nan for e in df_clean['Classification_set']]
df_clean['65sub2'] = [list(e)[200] if len(list(e)) > 198 else np.nan for e in df_clean['Classification_set']]
df_clean['Class66'] = [list(e)[201] if len(list(e)) > 201 else np.nan for e in df_clean['Classification_set']]
df_clean['66sub1'] = [list(e)[202] if len(list(e)) > 201 else np.nan for e in df_clean['Classification_set']]
df_clean['66sub2'] = [list(e)[203] if len(list(e)) > 201 else np.nan for e in df_clean['Classification_set']]
df_clean['Class67'] = [list(e)[204] if len(list(e)) > 204 else np.nan for e in df_clean['Classification_set']]
df_clean['67sub1'] = [list(e)[205] if len(list(e)) > 204 else np.nan for e in df_clean['Classification_set']]
df_clean['67sub2'] = [list(e)[206] if len(list(e)) > 204 else np.nan for e in df_clean['Classification_set']]

df_clean['Class62'] = [list(e)[207] if len(list(e)) > 186 else np.nan for e in df_clean['Classification_set']]
df_clean['62sub1'] = [list(e)[208] if len(list(e)) > 186 else np.nan for e in df_clean['Classification_set']]
df_clean['62sub2'] = [list(e)[209] if len(list(e)) > 186 else np.nan for e in df_clean['Classification_set']]
df_clean['Class63'] = [list(e)[210] if len(list(e)) > 189 else np.nan for e in df_clean['Classification_set']]
df_clean['63sub1'] = [list(e)[211] if len(list(e)) > 189 else np.nan for e in df_clean['Classification_set']]
df_clean['63sub2'] = [list(e)[212] if len(list(e)) > 189 else np.nan for e in df_clean['Classification_set']]
df_clean['Class64'] = [list(e)[213] if len(list(e)) > 192 else np.nan for e in df_clean['Classification_set']]
df_clean['64sub1'] = [list(e)[214] if len(list(e)) > 192 else np.nan for e in df_clean['Classification_set']]
df_clean['64sub2'] = [list(e)[215] if len(list(e)) > 192 else np.nan for e in df_clean['Classification_set']]
df_clean['Class65'] = [list(e)[216] if len(list(e)) > 195 else np.nan for e in df_clean['Classification_set']]
df_clean['65sub1'] = [list(e)[217] if len(list(e)) > 195 else np.nan for e in df_clean['Classification_set']]
df_clean['65sub2'] = [list(e)[218] if len(list(e)) > 195 else np.nan for e in df_clean['Classification_set']]
df_clean['Class66'] = [list(e)[219] if len(list(e)) > 198 else np.nan for e in df_clean['Classification_set']]
df_clean['66sub1'] = [list(e)[220] if len(list(e)) > 198 else np.nan for e in df_clean['Classification_set']]
df_clean['66sub2'] = [list(e)[221] if len(list(e)) > 198 else np.nan for e in df_clean['Classification_set']]
df_clean['Class67'] = [list(e)[222] if len(list(e)) > 201 else np.nan for e in df_clean['Classification_set']]
df_clean['67sub1'] = [list(e)[223] if len(list(e)) > 201 else np.nan for e in df_clean['Classification_set']]
df_clean['67sub2'] = [list(e)[224] if len(list(e)) > 201 else np.nan for e in df_clean['Classification_set']]
df_clean['Class68'] = [list(e)[225] if len(list(e)) > 204 else np.nan for e in df_clean['Classification_set']]
df_clean['68sub1'] = [list(e)[226] if len(list(e)) > 204 else np.nan for e in df_clean['Classification_set']]
df_clean['68sub2'] = [list(e)[227] if len(list(e)) > 204 else np.nan for e in df_clean['Classification_set']]
# Out:
# C:\Users\morge\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\morge\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\morge\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_clean.head()
# Out:
#   Patent Type            51        11            11A 13  25          21  \
# 1       Type1          A01N   1245584    EP3232777 A  A  En  18104999.3
# 2       Type1      A23B2018   1245585  CN107404887 A  A  Ja  18105388.9
# 3       Type1          A23C   1245586    EP3240429 A  A  En  18105103.3
# 4       Type1  A23LA61KA61P  1245588*  CN107427058 A  A  Ja  18104907.4
# 5       Type1      A24BA24F  1245589*    EP3297460 A  A  En  18105071.1
#
#            22                                        86                86A  \
# 1  18.04.2018     18.12.2015          PCT/EP2015/080688  PCT/EP2015/080688
# 2  25.04.2018     18.03.2016          PCT/JP2016/058840  PCT/JP2016/058840
# 3  19.04.2018     30.12.2015          PCT/US2015/068050  PCT/US2015/068050
# 4  16.04.2018  29.01.2016             PCT/JP2016/052638  PCT/JP2016/052638
# 5  19.04.2018     19.05.2016          PCT/EP2016/061313  PCT/EP2016/061313
#
#                                      87  \
# ...

# %%
df_clean.info(max_cols=280)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52148 entries, 1 to 64507
# Data columns (total 225 columns):
# Patent Type           52148 non-null object
# 51                    52148 non-null object
# 11                    52148 non-null object
# 11A                   52148 non-null object
# 13                    52148 non-null object
# 25                    52148 non-null object
# 21                    52148 non-null float64
# 22                    52148 non-null object
# 86                    52148 non-null object
# 86A                   52148 non-null object
# 87                    52148 non-null object
# 30                    52148 non-null object
# 62                    52148 non-null float64
# 54                    52148 non-null object
# 73N                   52148 non-null object
# 73C                   52148 non-null object
# 71N                   52148 non-null object
# 71C                   52148 non-null object
# 72                    52148 non-null object
# ...

# %%
df_clean.to_excel('testing.xlsx')
